# %% [markdown]
# <a href="https://colab.research.google.com/github/ardyansyah5711/Teknologi-Data/blob/main/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if False:
  print("False")
else:
  print("True")
# Out:
# True

# %%
nilai1 = 10
nilai2 = 20
nilai3 = 100
total = nilai1 + nilai2 + nilai3
print(total)
# Out:
# 130

# %%
cabang = ['Jakarta','Bogor','Bandung','Solo','Malang','Surabaya',
          'Banyuwangi','Denpasar','Makasar']
print(cabang)
# Out:
# ['Jakarta', 'Bogor', 'Bandung', 'Solo', 'Malang', 'Surabaya', 'Banyuwangi', 'Denpasar', 'Makasar']

# %%
x = 100; y=150; z=22.56; 
hasil = x+2*y*z
print(hasil)
# Out:
# 6868.0

# %%
# this is a comment
print ("Hello!")
# Out:
# Hello!

# %%
counter = 100
jarak = 104.5
name = "Ardyansyah"

a = b = c = 200
name, city, salary = "Malang", 'Surabaya', 70000

print(counter)
print(jarak)
print(name)
print(a, b, c)
print(city)
# Out:
# 100
# 104.5
# Malang
# 200 200 200
# Surabaya

# %%
print(True or False)

print(True and False)

print ( 100 > 200)

a=9
print (a > 0 )

b= 10
print ( a > b )
# Out:
# True
# False
# False
# True
# False

# %%
x = None
print(type(x))

print(x == None)
print(x)
# Out:
# <class 'NoneType'>
# True
# None

# %%
nama = 'Ardyansyah'

kalimat = "This is a sentence."

Paragraf = """This is a paragraph.
Paragraph are made up of several lines and sentences."""

print(nama)
print(kalimat)
print(Paragraf)

print(nama[0:5])
print(nama[2:])
print(kalimat[-8:-1])
# Out:
# Ardyansyah
# This is a sentence.
# This is a paragraph.
# Paragraph are made up of several lines and sentences.
# Ardya
# dyansyah
# entence

# %%
myStr = 'Hello, Surabaya'
print(len(myStr))

pegawai = 'Sabine'
print ("nama : ", pegawai)
print("pass" + "word")

age = 35
mytext = 'Age is'
print(mytext + str(age))

print("Python " * 3)
# Out:
# 15
# nama :  Sabine
# password
# Age is35
# Python Python Python

# %%
print('"Double" in Single')

print("\"Double\" in Double")
# Out:
# "Double" in Single
# "Double" in Double

# %%
s = "SaMurai"
s.lower()
print(s)
s2 = s.lower()
print(s2)

name = input('What is Your name ? ')

print('Hi ' + name + '!')
# Out:
# SaMurai
# samurai
# What is Your name ? Samurai
# Hi Samurai!

# %%
print(str(3.14))
print(int("2345"))
print(int(75.99999))
print(float("5.678"))
print(float(9))
# Out:
# 3.14
# 2345
# 75
# 5.678
# 9.0

# %%
a = 10; b = 20
mylist = [1,2,3,4,5 ];

a = 2
if (a in mylist):
  print ("Line 3 a is available in the given list")
else:
  print ("Line 3 a is not available is the given list")
# Out:
# Line 3 a is available in the given list
